# %%
import pandas as pd
from config import LENDING_CLUB_ACCEPTED
import utils

# %% [markdown]
# # SR 11-7 Model Validation Automation
#
# ## Part 1 - Model Overview
#
# ### Dataset: Lending Club Loan Data

# %%
lca_df = pd.read_csv(LENDING_CLUB_ACCEPTED, low_memory=False)

lca_data_dict = utils.generate_data_dictionary(lca_df, 5)

lca_data_dict
# Out:
#                                  Column Name Data Type  Missing Values  \
# id                                        id    object               0
# member_id                          member_id   float64         2260701
# loan_amnt                          loan_amnt   float64              33
# funded_amnt                      funded_amnt   float64              33
# funded_amnt_inv              funded_amnt_inv   float64              33
# ...                                      ...       ...             ...
# settlement_status          settlement_status    object         2226455
# settlement_date              settlement_date    object         2226455
# settlement_amount          settlement_amount   float64         2226455
# settlement_percentage  settlement_percentage   float64         2226455
# settlement_term              settlement_term   float64         2226455
#
#                        Unique Values Sample Value
# id                           2260701     68426831
# ...
